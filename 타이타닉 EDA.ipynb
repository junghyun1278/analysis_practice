# %% [markdown]
# # 타이타닉 데이터 를 활용한 데이터 분석1

# %% [markdown]
# ## train test데이터 kaggle에서 다운

# %%
import pandas as pd

train = pd.read_csv("C:/Users/jungh/Downloads/타이타닉/train.csv")
test = pd.read_csv("C:/Users/jungh/Downloads/타이타닉/test.csv")

# %% [markdown]
# ## EDA

# %% [markdown]
# ## 데이터 변수
# - survived : 생존=1, 죽음=0
# - pclass : 승객 등급. 1등급=1, 2등급=2, 3등급=3
# - sibsp : 함께 탑승한 형제 또는 배우자 수
# - parch : 함께 탑승한 부모 또는 자녀 수
# - ticket : 티켓 번호
# - cabin : 선실 번호
# - embarked : 탑승장소 S=Southhampton, C=Cherbourg, Q=Queenstown

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## train, test 구조 확인

# %%
print(train.shape)
print(test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# - 수치형 column은 통계적 수치로 표현이 되지면 문자형 column은 표현이 안되는 것을 볼수있다

# %% [markdown]
# ## 결측치 확인하기

# %%
#pip install missingno

# %%
import missingno as msno #결측치 시각화

import warnings #경고 무시
warnings.filterwarnings('ignore')

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
for col in train.columns:
    msg = 'column: {:>10}\t Precent of Nan value: {:.2f}%'.format(col, 100*(train[col].isnull().sum()/train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Precent of Nan value: 0.00%
# column:   Survived	 Precent of Nan value: 0.00%
# column:     Pclass	 Precent of Nan value: 0.00%
# column:       Name	 Precent of Nan value: 0.00%
# column:        Sex	 Precent of Nan value: 0.00%
# column:        Age	 Precent of Nan value: 19.87%
# column:      SibSp	 Precent of Nan value: 0.00%
# column:      Parch	 Precent of Nan value: 0.00%
# column:     Ticket	 Precent of Nan value: 0.00%
# column:       Fare	 Precent of Nan value: 0.00%
# column:      Cabin	 Precent of Nan value: 77.10%
# column:   Embarked	 Precent of Nan value: 0.22%

# %%
for col in test.columns:
    m_v = 'column: {:>10}\t Precent of Nan value: {:.2f}%'.format(col, 100*(test[col].isnull().sum()/test[col].shape[0]))
    print(msg)
# Out:
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%
# column:   Embarked	 Precent of Nan value: 0.22%

# %%
msno.matrix(df= train.iloc[:,:], figsize=(10,10), color=(1,0.5,0.2))
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df= test.iloc[:,:], figsize=(10,10), color=(1,0.5,0.8))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df=train.iloc[:,:], figsize=(8,8), color=(0.3,0.5,0.2))
# Out:
# <AxesSubplot:>

# %% [markdown]
# - train test에 Age,Cabin,Embarked에 결측치가 있는것을 확인

# %% [markdown]
# ## 생존

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
# 1.파이차트로 퍼센트로 확인
train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct = '%1.1f%%', ax=ax[0], shadow=True)
#explode 간격, autopct 레이블, ax=ax[0] plot의 위치, shadow 그림자
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
# 2. 막대 그래프로 생존 인원 확인
sns.countplot('Survived', data=train, ax=ax[1]) # sns.countplot('변수','데이터')
ax[1].set_title('Count plot - Survived')
plt.show()

# %% [markdown]
# ## Pclass별 생존 확인

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index = True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
pd.crosstab(train['Pclass'], train['Survived'], margins = True).style.background_gradient(cmap = 'ocean')
# Out:
# <style  type="text/css" >
# #T_9d7ca_row0_col0,#T_9d7ca_row1_col1,#T_9d7ca_row1_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_9d7ca_row0_col1{
#             background-color:  #003631;
#             color:  #f1f1f1;
#         }#T_9d7ca_row0_col2{
#             background-color:  #006f0b;
#             color:  #f1f1f1;
#         }#T_9d7ca_row1_col0{
#             background-color:  #007209;
#             color:  #f1f1f1;
#         }#T_9d7ca_row2_col0{
#             background-color:  #006f9f;
#             color:  #f1f1f1;
#         }#T_9d7ca_row2_col1{
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }#T_9d7ca_row2_col2{
#             background-color:  #00276f;
#             color:  #f1f1f1;
#         }#T_9d7ca_row3_col0,#T_9d7ca_row3_col1,#T_9d7ca_row3_col2{
#             background-color:  #ffffff;
#             color:  #000000;
# ...

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index = True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
y_position = 1.02 # 타이틀이 그래프 위에서 얼마나 떨어지는지 정하는 값
f, ax = plt.subplots(1,2,figsize=(18,8))

train['Pclass'].value_counts().plot.bar(color=['pink','blue','yellow'], ax=ax[0])
ax[0].set_title('Pclass별 타있는 인원수')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=train,ax=ax[1]) #hue 생존 죽음 색깔 구분
ax[1].set_title('Pclass별 생존여부')
plt.show()

# %% [markdown]
# - 낮은 등급일수록 인원수가 많이 타있는 것을 확인
# - 높은 등급일수록 생존 확률이 더 높았던 것을 확인

# %% [markdown]
# ## Sex별 생존 확인

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index = True).count()
# Out:
#         Survived
# Sex
# female       314
# male         577

# %%
pd.crosstab(train['Sex'], train['Survived'], margins = True).style.background_gradient(cmap = 'ocean')
# Out:
# <style  type="text/css" >
# #T_d8cdd_row0_col0,#T_d8cdd_row0_col2,#T_d8cdd_row1_col1{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_d8cdd_row0_col1{
#             background-color:  #004d88;
#             color:  #f1f1f1;
#         }#T_d8cdd_row1_col0{
#             background-color:  #7bbdd3;
#             color:  #000000;
#         }#T_d8cdd_row1_col2{
#             background-color:  #002f74;
#             color:  #f1f1f1;
#         }#T_d8cdd_row2_col0,#T_d8cdd_row2_col1,#T_d8cdd_row2_col2{
#             background-color:  #ffffff;
#             color:  #000000;
# ...

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index = True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
train['Sex'].value_counts().plot.bar(color=['pink','blue'], ax=ax[0])
ax[0].set_title('Sex에 따른 타있는 인원수')
ax[0].set_ylabel('Count')
sns.countplot('Sex',hue='Survived',data=train,ax=ax[1])
ax[1].set_title('Sex에 따른 생존여부')
plt.show()

# %% [markdown]
# - 여성의 경우 남성보다 생존 확률이 높은 모습을 보임

# %% [markdown]
# ## Sex와 Pclass의 생존 관계
# - factor plot을 이용한 시각화 (그리드 분할 그래프)

# %%
sns.factorplot('Pclass', 'Survived', hue= 'Sex', data=train, size=6, aspect=1.5)

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
              data=train, satureation=1,
               size=9, aspect=1) # satureation - 포화, aspect - 측면

# %% [markdown]
# - 여성의 경우 남성 보다 생존 확률이 높은 것을 볼 수 있음
# - Pclass가 높을 수록 생존 확률이 높은 것을 볼 수 있음

# %% [markdown]
# ## Age에 따른 생존 여부
# - kdeplot을 이용한 시각화 (커널 밀도 그래프, kernel density estimation)

# %%
print("제일 나이 많은 탑승객: {:.1f}살".format(train['Age'].max()))
print("제일 어린 탑승객: {:.1f}살".format(train['Age'].min()))
print("탑승객 평균 나이: {:.1f}살".format(train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객: 80.0살
# 제일 어린 탑승객: 0.4살
# 탑승객 평균 나이: 29.7살

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(train[train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(train[train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['생존', '죽음'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
train['Age'][train['Pclass'] == 1].plot(kind='kde')
train['Age'][train['Pclass'] == 2].plot(kind='kde')
train['Age'][train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Pclass에 따른 Age 밀도')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(train[(train['Survived'] == 1) & (train['Pclass'] == 1)]['Age'], ax=ax)
sns.kdeplot(train[(train['Survived'] == 0) & (train['Pclass'] == 1)]['Age'], ax=ax)
plt.title('Pclass = 1')
plt.legend(['생존', '죽음'])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(train[(train['Survived'] == 1) & (train['Pclass'] == 2)]['Age'], ax=ax)
sns.kdeplot(train[(train['Survived'] == 0) & (train['Pclass'] == 2)]['Age'], ax=ax)
plt.title('Pclass = 2')
plt.legend(['생존', '죽음'])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(train[(train['Survived'] == 1) & (train['Pclass'] == 3)]['Age'], ax=ax)
sns.kdeplot(train[(train['Survived'] == 0) & (train['Pclass'] == 3)]['Age'], ax=ax)
plt.title('Pclass = 3')
plt.legend(['생존', '죽음'])
plt.show()

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(train[train['Age'] < i]['Survived'].sum() / len(train[train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('연령별 누적 생존 률', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# - 위 그래프와 같이 연령이 증가할수록 생존률이 감소하는 모습이 보여짐

# %% [markdown]
# ## Pclass,Sex,Age에 따른 생존 여부

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass","Age", hue = 'Survived', data=train, scale='count', split=True, ax = ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))

sns.violinplot("Sex","Age", hue="Survived", data=train, scale='count', split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# - Pclass가 높을수록 생존률이 높다
# - 남성보다 여성의 생존률이 높다
# - 20~50대 생존률이 높다

# %% [markdown]
# ## Embarked

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)
plt.title('Embarked별 생존률')
plt.show()

# %%
f,ax=plt.subplots(2, 2, figsize=(20,15))

sns.countplot('Embarked', data=train, ax=ax[0,0])
ax[0,0].set_title('(1) No. Of Passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=train, ax=ax[1,0])
ax[1,0].set_title('(3) Embarked vs Survived')

sns.countplot('Embarked', hue='Pclass', data=train, ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# ## Fare

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
sns.distplot(train['Fare'], color='b', label='Skewness : {:.2f}'.format(train['Fare'].skew()), ax=ax)
ax.legend(loc='best')

# %% [markdown]
# ## Ticket

# %%
train['Ticket'].value_counts()
# Out:
# CA. 2343    7
# 1601        7
# 347082      7
# 3101295     6
# 347088      6
#            ..
# 370370      1
# PC 17596    1
# 226593      1
# 65306       1
# 112059      1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# ## 결측값 채우기

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print('Age의 값 분포: \n',train['Age'].value_counts())
print('\nCabin의 값 분포: \n',train['Cabin'].value_counts())
print('\nEmbarked의 값 분포: \n',train['Embarked'].value_counts())
# Out:
# Age의 값 분포:
#  24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: Age, Length: 88, dtype: int64
#
# Cabin의 값 분포:
#  B96 B98        4
# C23 C25 C27    4
# G6             4
# D              3
# F33            3
#               ..
# D50            1
# C128           1
# E40            1
# C148           1
# B3             1
# Name: Cabin, Length: 147, dtype: int64
#
# Embarked의 값 분포:
#  S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Age'].fillna(train['Age'].mean(),inplace =True)
train['Cabin'].fillna('N',inplace=True)
train['Embarked'].fillna('S',inplace=True)

# %% [markdown]
# - Age는 평균값으로 대체
# - Cabin는 N으로 대체
# - Embarked는 S의 분포가 가장 많아 S로 대체

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train['Cabin'] = train['Cabin'].str[:1]

# %% [markdown]
# - Cabin의 글자를 1번째만 나타내도록 변환

# %%
def get_category(age):
    cat = ''
    if age <= -1: cat = 'Unknown'
    elif age <= 5: cat = 'Baby'
    elif age <= 12: cat = 'Child'
    elif age <= 18: cat = 'Teenager'
    elif age <= 25: cat = 'Student'
    elif age <= 35: cat = 'Young Adult'
    elif age <= 60: cat = 'Adult'
    else : cat = 'Elderly'
    
    return cat

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

#X축의 값을 순차적으로 표시하기 위한 설정 
group_names = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Elderly']

# lambda 식에 위에서 생성한 get_category( ) 함수를 반환값으로 지정. 
# get_category(X)는 입력값으로 'Age' 컬럼값을 받아서 해당하는 cat 반환
train['Age_cat'] = train['Age'].apply(lambda x : get_category(x))
sns.barplot(x='Age_cat', y = 'Survived', hue='Sex', data=train, order=group_names,ax=ax)
ax.legend(loc ='best')
train.drop('Age_cat', axis=1, inplace=True)

# %%
from sklearn import preprocessing

def encode_features(dataDF):
    features = ['Cabin', 'Sex', 'Embarked']
    for feature in features:
        le = preprocessing.LabelEncoder()
        le = le.fit(dataDF[feature])
        dataDF[feature] = le.transform(dataDF[feature])
        
    return dataDF

titanic_df = encode_features(train)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Cabin  Embarked
# 0         A/5 21171   7.2500      7         2
# 1          PC 17599  71.2833      2         0
# 2  STON/O2. 3101282   7.9250      7         2
# 3            113803  53.1000      2         2
# 4            373450   8.0500      7         2
